# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# read data
df=pd.read_csv(r'C:\Users\Ghassen\Desktop\project\datasets\Movie_classification.csv',header=0)

# %%
#show 19 rows max.
pd.set_option('display.max_rows',19)
#show all columns
pd.set_option('display.max_columns',19)

# %%
#display the first 10 rows
df.head(10)
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
# 5            20.5970               59.36               0.542  35718.650
# 6            21.7658               70.74               0.476  33396.660
# 7            22.8910               70.74               0.476  34285.460
# 8            24.2248               70.74               0.476  31280.205
# 9            23.4008               70.74               0.476  33352.220
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# ...

# %%
#dimension data
df.shape
# Out:
# (506, 19)

# %%
#display the different types that exist
df.dtypes.value_counts()
# Out:
# float64    12
# int64       5
# object      2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# Marketing expense      506 non-null float64
# Production expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             494 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# Num_multiplex          506 non-null int64
# Collection             506 non-null int64
# Start_Tech_Oscar       506 non-null int64
# ...

# %%
#the percentage of NA by each column
(df.isna().sum()/df.shape[0]).sort_values()
# Out:
# Marketing expense      0.000000
# Num_multiplex          0.000000
# Avg_age_actors         0.000000
# Genre                  0.000000
# Twitter_hastags        0.000000
# 3D_available           0.000000
# Trailer_views          0.000000
# Collection             0.000000
# Critic_rating          0.000000
# Director_rating        0.000000
# Lead_Actress_rating    0.000000
# Lead_ Actor_Rating     0.000000
# Movie_length           0.000000
# Budget                 0.000000
# Multiplex coverage     0.000000
# Production expense     0.000000
# Producer_rating        0.000000
# Start_Tech_Oscar       0.000000
# Time_taken             0.023715
# dtype: float64

# %%
#display the NA by each column
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(),cbar=False)

# %%
df.head(10)
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
# 5            20.5970               59.36               0.542  35718.650
# 6            21.7658               70.74               0.476  33396.660
# 7            22.8910               70.74               0.476  34285.460
# 8            24.2248               70.74               0.476  31280.205
# 9            23.4008               70.74               0.476  33352.220
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# ...

# %%
#display the different variables that exist in each column('3D_available') with their percentage(normalize=True)
df['3D_available'].value_counts(normalize=True)
# Out:
# YES    0.551383
# NO     0.448617
# Name: 3D_available, dtype: float64

# %%
#display the different variables that exist in each column in graphic
sns.countplot(x='3D_available',data=df)

# %%
df.Genre.value_counts()
# Out:
# Thriller    183
# Comedy      155
# Drama        97
# Action       71
# Name: Genre, dtype: int64

# %%
sns.countplot(x='Genre',data=df)

# %%
df.Avg_age_actors.value_counts()
# Out:
# 57    20
# 22    19
# 40    18
# 23    18
# 20    17
#       ..
# 44     7
# 49     6
# 32     6
# 33     2
# 3      1
# Name: Avg_age_actors, Length: 42, dtype: int64

# %%
#display for each gender the age averages
sns.catplot(x="Genre", y="Avg_age_actors", kind="box", data=df)

# %%
df['Collection'].value_counts()
# Out:
# 100000    16
# 50000      8
# 46200      7
# 43400      7
# 38800      6
#           ..
# 63400      1
# 56400      1
# 23800      1
# 35400      1
# 87000      1
# Name: Collection, Length: 228, dtype: int64

# %%
#descriptive statistics summary
df.Collection.describe()
# Out:
# count       506.000000
# mean      45057.707510
# std       18364.351764
# min       10000.000000
# 25%       34050.000000
# 50%       42400.000000
# 75%       50000.000000
# max      100000.000000
# Name: Collection, dtype: float64

# %%
#histogram
sns.distplot(df['Collection'])

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Collection'].skew())
print("Kurtosis: %f" % df['Collection'].kurt())
# Out:
# Skewness: 1.110912
# Kurtosis: 1.516783

# %%
#scatter plot Budget/Collection
var = 'Budget'
data = pd.concat([df['Collection'], df[var]], axis=1)
data.plot.scatter(x=var, y='Collection', ylim=(0,100000));

# %%
#scatter plot Production expense/Collection
var = 'Production expense'
data = pd.concat([df['Collection'], df[var]], axis=1)
data.plot.scatter(x=var, y='Collection', ylim=(0,100000));

# %%
#scatter plot Marketing expense/Collection
var = 'Marketing expense'
data = pd.concat([df['Collection'], df[var]], axis=1)
data.plot.scatter(x=var, y='Collection', ylim=(0,100000));

# %%
#box plot Genre/Collection
var = 'Genre'
data = pd.concat([df['Collection'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="Collection", data=data)
fig.axis(ymin=0, ymax=100000);

# %%
#box plot 3D_available/Collection
var = '3D_available'
data = pd.concat([df['Collection'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="Collection", data=data)
fig.axis(ymin=0, ymax=100000);
plt.xticks(rotation=90);

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#correlation clustermatrix
corrmat = df.corr()

sns.clustermap(corrmat)

# %%
#Collection correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Collection')['Collection'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#scatterplot
sns.set()
cols = ['Collection', 'Trailer_views', 'Budget', 'Multiplex coverage', 'Start_Tech_Oscar', 'Genre']
sns.pairplot(df[cols], size = 2.5)
plt.show()

# %% [markdown]
# ### Missing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# Marketing expense      506 non-null float64
# Production expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             494 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# Num_multiplex          506 non-null int64
# Collection             506 non-null int64
# Start_Tech_Oscar       506 non-null int64
# ...

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(19)
# Out:
#                      Total   Percent
# Time_taken              12  0.023715
# Start_Tech_Oscar         0  0.000000
# Producer_rating          0  0.000000
# Production expense       0  0.000000
# Multiplex coverage       0  0.000000
# Budget                   0  0.000000
# Movie_length             0  0.000000
# Lead_ Actor_Rating       0  0.000000
# Lead_Actress_rating      0  0.000000
# Director_rating          0  0.000000
# Critic_rating            0  0.000000
# Collection               0  0.000000
# Trailer_views            0  0.000000
# 3D_available             0  0.000000
# Twitter_hastags          0  0.000000
# Genre                    0  0.000000
# Avg_age_actors           0  0.000000
# Num_multiplex            0  0.000000
# Marketing expense        0  0.000000

# %%
#dealing with missing data
df['Time_taken'].mean()
df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# Marketing expense      506 non-null float64
# Production expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             506 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# Num_multiplex          506 non-null int64
# Collection             506 non-null int64
# Start_Tech_Oscar       506 non-null int64
# ...

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler

saleprice_scaled = StandardScaler().fit_transform(df['Collection'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.91089788]
#  [-1.91089788]
#  [-1.84548923]
#  [-1.76917913]
#  [-1.69286904]
#  [-1.69286904]
#  [-1.67106615]
#  [-1.67106615]
#  [-1.67106615]
#  [-1.64926327]]
#
# outer range (high) of the distribution:
# [[2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]
#  [2.99475117]]

# %%
#bivariate analysis Collection/Budget
var = 'Budget'
data = pd.concat([df['Collection'], df[var]], axis=1)
data.plot.scatter(x=var, y='Collection', ylim=(0,100000));
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#bivariate analysis Collection/Trailer_views
var = 'Trailer_views'
data = pd.concat([df['Collection'], df[var]], axis=1)
data.plot.scatter(x=var, y='Collection', ylim=(0,100000));
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#histogram and normal probability plot
from scipy.stats import norm
from scipy import stats

sns.distplot(df['Collection'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Collection'], plot=plt)

# %%
#applying log transformation
df['Collection'] = np.log(df['Collection'])

# %%
#transformed histogram and normal probability plot
sns.distplot(df['Collection'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Collection'], plot=plt)

# %%
#histogram and normal probability plot
sns.distplot(df['Budget'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Budget'], plot=plt)

# %%
#data transformation
df['Budget'] = np.log(df['Budget'])

# %%
#transformed histogram and normal probability plot
sns.distplot(df['Budget'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Budget'], plot=plt)

# %%
#histogram and normal probability plot
sns.distplot(df['Trailer_views'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Trailer_views'], plot=plt)

# %%
#data transformation
df['Trailer_views'] = np.log(df['Trailer_views'])

# %%
#transformed histogram and normal probability plot
sns.distplot(df['Trailer_views'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Trailer_views'], plot=plt)

# %%
#scatter plot
plt.scatter(df['Budget'], df['Collection'])

# %%
#scatter plot
plt.scatter(df['Trailer_views'], df['Collection'])

# %% [markdown]
# ### Dummy Variable

# %%
#qualitative variables
for col in df.select_dtypes('object'):
    print(f'{col :-<50}, {df[col].unique()}')
# Out:
# 3D_available--------------------------------------, ['YES' 'NO']
# Genre---------------------------------------------, ['Thriller' 'Drama' 'Comedy' 'Action']

# %%
#Dummy Variable Creation
df = pd.get_dummies(df,columns = ["3D_available","Genre"],drop_first = True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  10.505728
# 1            20.5462               69.14               0.531  10.482028
# 2            20.5458               69.14               0.531  10.594449
# 3            20.6474               59.36               0.542  10.568078
# 4            21.3810               59.36               0.542  10.589146
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  ...  Twitter_hastags  Avg_age_actors  Num_multiplex  \
# ...
